# %% [markdown]
# <a href="https://colab.research.google.com/github/KatrinFrimus/Introduction-to-cloud-computing/blob/main/tirgul4_cloud.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import json

from google.colab import drive
drive.mount('/content/drive',force_remount=True)
#dictionary = json.load(open('/content/drive/My Drive/data.json', 'r'))
#df2 = pd.read_json('/content/drive/My Drive/data.json')
dic = pd.read_json('/content/drive/My Drive/data.json')
print(df2.to_string())
# Out:
# Mounted at /content/drive
#                    Time                  Document                   Tab       User                                                      Description
# 0   2023-01-13 14:12:54      Industry 4.0 Project                   N/A  StudentA1                                                   Close document
# 1   2023-01-13 14:12:53      Industry 4.0 Project  Part Studio 2 Copy 1  StudentA1  Tab Part Studio 2 Copy 1 of type PARTSTUDIO closed by StudentA1
# 2   2023-01-13 13:27:38      Industry 4.0 Project  Part Studio 2 Copy 1  StudentA1                                                       Hide Right
# 3   2023-01-13 13:27:37      Industry 4.0 Project  Part Studio 2 Copy 1  StudentA1                                                       Hide Front
# 4   2023-01-13 13:27:37      Industry 4.0 Project  Part Studio 2 Copy 1  StudentA1                                                         Hide Top
# ...

# %%
from IPython.display import clear_output
from IPython.display import display
def build_graph(value):
  clear_output(wait=True)
  display(w)
  filter_value = dic[value.new].value_counts()
  filter_value.plot(kind='bar')
  plt.title('Number of Operations by '+value.new)
  plt.xlabel(value.new)
  plt.ylabel('Number of Operations')
  plt.xticks(rotation=45)
  plt.tight_layout()
  plt.show()

# %%
import ipywidgets as widgets
from IPython.display import display
w = widgets.Dropdown(
    options=['Choose a filter','Time','Document','Tab','User'],
    value='Choose a filter',
    description='filter:',
)

w.observe(build_graph,names='value')
display(w)
# Out:
# Dropdown(description='filter:', index=1, options=('Choose a filter', 'Time', 'Document', 'Tab', 'User'), value…
