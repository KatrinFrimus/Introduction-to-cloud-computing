# %% [markdown]
# <a href="https://colab.research.google.com/github/KatrinFrimus/Introduction-to-cloud-computing/blob/main/HW2_bear_new.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install requests beautifulsoup4
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.31.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.12.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.7.4)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.5)

# %%
# !pip install firebase
# Out:
# Requirement already satisfied: firebase in /usr/local/lib/python3.10/dist-packages (4.0.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from firebase) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->firebase) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->firebase) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->firebase) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->firebase) (2024.7.4)

# %%
# !apt-get install wkhtmltopdf
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# wkhtmltopdf is already the newest version (0.12.6-2).
# 0 upgraded, 0 newly installed, 0 to remove and 44 not upgraded.

# %%
import requests
from bs4 import BeautifulSoup
from collections import Counter
import re

# %%
def fetch_page(url):
    response = requests.get(url)
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        return soup
    else:
        return None

# %%
def index_words(soup):
    index = {}
    words = re.findall(r'\w+', soup.get_text())
    for word in words:
        word = word.lower()
        if word in index:
            index[word] += 1
        else:
            index[word] = 1
    return index

# %%
def remove_stop_words(index):
    stop_words = {'i', 'me', 'my', 'myself', 'we', 'our', 'ours',
'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself',
'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself',
'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves',
 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are',
 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing',
 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for',
'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to',
'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once',
'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most',
'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very',
's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y',
 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't",
'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn',
 "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't",
'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't",'n','also'}
    for stop_word in stop_words:
        if stop_word in index:
            del index[stop_word]
    return index

# %%
from nltk.stem import PorterStemmer
def apply_stemming(index):
    stemmer = PorterStemmer()
    stemmed_index = {}
    for word, count in index.items():
        stemmed_word = stemmer.stem(word)
        if stemmed_word in stemmed_index:
            stemmed_index[stemmed_word] += count
        else:
            stemmed_index[stemmed_word] = count
    return stemmed_index

# %%
def search(query, index):

    stemmer = PorterStemmer()
    query_words = re.findall(r'\w+', query.lower())
    print(query)
    results = {}
    for word in query_words:
        word = stemmer.stem(word)
        if word in index:
            results[word] = index[word]
    return results

# %%
def search_engine(url):
    soup = fetch_page(url)
    if soup is None:
        return None
    index = index_words(soup)
    index = remove_stop_words(index)
    index = apply_stemming(index)
    #results = search(query, index)
    sorted_by_values = dict(sorted(index.items(), key=lambda item: item[1], reverse=True))
    #print("Sorted by values:", sorted_by_values)
    return sorted_by_values

# %%
import pandas as pd
url = 'https://cad.onshape.com/help/Content/Glossary/glossary.htm'
results = search_engine(url)
print(results)
df = pd.DataFrame(list(results.items()), columns=['Term', 'Frequency'])
df=df.head(15)
print(df.to_string(index=False))
# Out:
# {'context': 676, 'type': 656, 'see': 638, 'keyboard': 631, 'shortcut': 631, 'plan': 626, 'part': 524, 'studio': 369, 'assembl': 279, 'draw': 226, 'sketch': 220, 'select': 185, 'creat': 174, 'enterpris': 166, 'document': 164, 'render': 159, 'view': 151, 'simul': 149, 'profession': 145, 'use': 139, 'tool': 130, 'featur': 118, 'mate': 109, 'onshap': 98, 'menu': 98, 'face': 94, 'option': 86, 'edg': 86, 'panel': 77, 'appear': 76, 'surfac': 75, 'point': 74, 'sheet': 70, 'allow': 67, 'plane': 67, 'model': 63, 'open': 61, 'list': 58, 'enabl': 55, 'curv': 55, 'display': 53, 'properti': 52, 'tabl': 52, 'one': 51, 'dimens': 49, 'shift': 49, 'instanc': 47, 'show': 47, 'color': 47, 'entiti': 47, 'two': 46, 'new': 46, 'connect': 45, 'user': 43, 'line': 42, 'metal': 41, 'load': 40, 'current': 40, 'edit': 40, 'camera': 40, 'tab': 38, 'workspac': 38, 'geometri': 37, 'version': 36, 'environ': 36, 'axi': 34, 'account': 33, 'set': 33, 'hide': 33, 'defin': 32, 'dialog': 32, 'submenu': 30, 'rotat': 30, 'place': 29, 'scale': 29, 'exist': 28, 'materi': 27, 'custom': 27, 'insert': 27, 'along': 26, 'add': 26, 'graphic': 25, 'area': 25, 'file': 24, 'comment': 24, 'appli': 24, 'connector': 24, 'relat': 24, 'x': 24, 'center': 24, 'locat': 24, 'default': 23, 'multipl': 23, 'circl': 22, 'arc': 22, 'region': 22, 'delet': 22, 'ctrl': 21, 'right': 21, 'within': 21, 'base': 21, 'object': 21, 'intersect': 21, 'end': 20, 'may': 20, 'control': 20, 'command': 20, 'name': 20, 'reflect': 20, 'visual': 20, 'format': 20, 'page': 19, 'scene': 19, 'element': 19, 'import': 19, 'construct': 19, 'configur': 19, 'key': 19, 'top': 18, 'specifi': 18, 'toggl': 18, 'hole': 18, 'pattern': 18, 'z': 18, 'make': 18, 'time': 18, 'dome': 18, 'stress': 18, 'bar': 17, 'avail': 17, 'provid': 17, 'qualiti': 17, 'degre': 17, 'method': 17, 'state': 17, 'system': 17, 'move': 17, 'filter': 16, 'includ': 16, 'chang': 16, 'ad': 16, 'section': 16, 'direct': 16, 'contain': 16, 'well': 16, 'posit': 16, 'specif': 16, 'variabl': 16, 'refer': 16, 'project': 16, 'repres': 15, 'close': 15, 'featurescript': 15, 'remov': 15, 'textur': 15, 'movement': 15, 'zoom': 15, 'analysi': 15, 'composit': 15, 'transmiss': 15, 'centerlin': 14, 'linear': 14, 'action': 14, 'applic': 14, 'folder': 14, 'distanc': 14, 'angl': 14, 'branch': 14, 'click': 14, 'left': 14, 'planar': 14, 'search': 13, 'anoth': 13, 'circular': 13, 'webgl': 13, 'result': 13, 'help': 13, 'corner': 13, 'assign': 13, 'toolbar': 13, 'imag': 13, 'align': 13, 'exampl': 13, 'bend': 13, 'subassembl': 13, 'function': 13, 'histori': 13, 'profil': 13, 'share': 13, 'access': 13, 'volum': 13, 'field': 13, 'standard': 12, 'perform': 12, 'vertic': 12, 'item': 12, 'activ': 12, 'paramet': 12, 'side': 12, 'text': 12, 'automat': 12, 'modifi': 12, 'bottom': 12, 'trim': 12, 'map': 12, 'non': 12, 'virtual': 12, 'curvatur': 12, 'valu': 12, 'solid': 12, 'extens': 11, 'support': 11, 'three': 11, 'spline': 11, 'number': 11, 'switch': 11, 'releas': 11, 'light': 11, 'mass': 11, 'polygon': 11, 'bond': 11, 'normal': 11, 'sharp': 11, 'icon': 11, 'group': 11, 'copi': 11, 'tangent': 11, 'bound': 11, 'compon': 11, 'extend': 11, 'take': 11, 'offset': 11, 'transform': 11, 'content': 10, '2': 10, '3d': 10, '3': 10, 'measur': 10, 'effect': 10, 'box': 10, 'window': 10, 'orient': 10, 'annot': 10, 'bodi': 10, 'like': 10, 'mode': 10, 'associ': 10, 'transpar': 10, 'first': 10, 'entir': 10, 'q': 10, 'fillet': 10, 'templat': 10, 'frame': 10, 'translat': 10, 'deform': 10, 'last': 10, 'perspect': 10, 'equal': 10, 'wall': 10, 'modal': 10, 'manag': 10, 'softwar': 9, 'cut': 9, 'differ': 9, 'note': 9, 'symbol': 9, 'addit': 9, 'boundari': 9, 'insid': 9, 'bump': 9, 'space': 9, 'cylindr': 9, 'date': 9, 'axe': 9, 'singl': 9, 'hidden': 9, 'highlight': 9, 'arrow': 9, 'shade': 9, 'across': 8, 'rectangl': 8, 'parallel': 8, 'height': 8, 'callout': 8, 'store': 8, 'tessel': 8, 'touch': 8, 'depth': 8, 'order': 8, 'updat': 8, 'determin': 8, 'either': 8, 'precis': 8, 'entri': 8, 'drive': 8, 'design': 8, 'replac ...
#      Term  Frequency
#   context        676
#      type        656
#       see        638
#  keyboard        631
#  shortcut        631
#      plan        626
#      part        524
#    studio        369
#   assembl        279
#      draw        226
#    sketch        220
#    select        185
#     creat        174
# enterpris        166
#  document        164

# %%
import datetime
def split_time(record):
    dt = datetime.datetime.strptime(record["Time"], "%Y-%m-%d %H:%M:%S")
    record["Date"] = dt.date().strftime("%Y-%m-%d")
    record["Time"] = dt.time().strftime("%H:%M:%S")
    return record

# Apply the function to each record in the list

# Output the updated data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import json
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
#dictionary = json.load(open('/content/drive/My Drive/data.json', 'r'))
#df2 = pd.read_json('/content/drive/My Drive/data.json')
#dic = pd.read_json('/content/drive/My Drive/data.json')
with open('/content/drive/My Drive/data.json_label', "r") as fid:
     z = json.load(fid)
for record in z:
  split_time(record)
df = pd.DataFrame(z)
print(df)
# Out:
# Mounted at /content/drive
#          Time      Document  \
# 0    08:05:26  ex2StudentB1
# 1    08:05:26  ex2StudentB1
# 2    08:05:12  ex2StudentB1
# 3    08:05:11  ex2StudentB1
# 4    15:09:31  ex2StudentB1
# ..        ...           ...
# 949  17:38:25  ex2StudentB1
# 950  17:38:22  ex2StudentB1
# 951  17:38:22  ex2StudentB1
# 952  17:38:22  ex2StudentB1
# 953  17:38:21  ex2StudentB1
#
#                                                    Tab      User  \
# 0                                                  N/A  StudentA
# 1                                        Part Studio 1  StudentA
# 2                                        Part Studio 1  StudentA
# 3                                                  N/A  StudentA
# 4                                                  N/A  StudentB
# ..                                                 ...       ...
# 949                                                N/A  StudentB
# 950                                         Assembly 1  StudentB
# 951                                      Part Studio 1  StudentB
# 952  Robot Gripper Instruction Sheet - Onshape Proj...  StudentB
# 953                                                N/A  StudentB
#
#                                            Description        Date
# 0                                       Close document  2023-03-26
# 1    Tab Part Studio 1 of type PARTSTUDIO closed by...  2023-03-26
# 2    Tab Part Studio 1 of type PARTSTUDIO opened by...  2023-03-26
# 3                                        Open document  2023-03-26
# 4                                       Close document  2023-03-25
# ..                                                 ...         ...
# 949                                     Update version  2023-03-20
# 950  Tab Assembly 1 of type ASSEMBLY created byStud...  2023-03-20
# 951  Tab Part Studio 1 of type PARTSTUDIO created b...  2023-03-20
# 952  Tab Robot Gripper Instruction Sheet - Onshape ...  2023-03-20
# 953                                    Create document  2023-03-20
#
# [954 rows x 6 columns]

# %%
from os import name
from firebase import firebase

firebase = firebase.FirebaseApplication('https://projectgroupbearcloud-default-rtdb.firebaseio.com/', None)
#result = firebase.post('/ProjectGroupBearCloud/',z)

result = firebase.get('/ProjectGroupBearCloud/-O2ExVKk-qC2MaCBpJbK', None)

df=pd.DataFrame(result)

# %%
import pandas as pd
import ipywidgets as widgets
from IPython.display import display, clear_output
import matplotlib.pyplot as plt
from google.colab import files



fig = None  # Global variable to hold the reference to the figure

# Function to save the current graph to a PDF and download it
def create_pdfs(button):
    global fig
    if fig:
        fig.savefig('graph.pdf')
        files.download('graph.pdf')

# Function to build and display the graph based on the selected value
def build_graph(change):
    global fig
    clear_output(wait=True)
    display(w)
    display(button)

    selected_value = change.new
    if selected_value and selected_value != 'Choose a filter':
        filter_value = df[selected_value].value_counts()
        fig, ax = plt.subplots()
        filter_value.plot(kind='bar', ax=ax)
        ax.set_title('Number of Operations by ' + selected_value)
        ax.set_xlabel(selected_value)
        ax.set_ylabel('Number of Operations')
        plt.xticks(rotation=45)
        plt.tight_layout()
        plt.show()

# Create a dropdown widget for selecting the filter
w = widgets.Dropdown(
    options=['Choose a filter', 'Time', 'Document', 'Tab', 'User', 'Date'],
    value='Choose a filter',
    description='Filter:',
)

# Create a button to trigger PDF creation
button = widgets.Button(description="Create PDF")
button.on_click(create_pdfs)

# Observe changes in the dropdown to update the graph
w.observe(build_graph, names='value')

# Initial display
display(w)
display(button)
# Out:
# Dropdown(description='Filter:', options=('Choose a filter', 'Time', 'Document', 'Tab', 'User', 'Date'), value=…
# Button(description='Create PDF', style=ButtonStyle())

# %%
import pandas as pd
import ipywidgets as widgets
from IPython.display import display, clear_output
from google.colab import files




filtered_df = df  # Global variable to hold the reference to the filtered DataFrame

def update_value_options(change):
    selected_key = key_dropdown.value
    value_dropdown.options = df[selected_key].unique() if selected_key else []

def display_filtered_table(change):
    global filtered_df
    selected_key = key_dropdown.value
    selected_value = value_dropdown.value

    if selected_key and selected_value:
        # Filter the DataFrame based on the selected key and value
        try:
            filtered_df = df[df[selected_key] == selected_value]
        except Exception as e:
            print(f"Error: {e}")
            filtered_df = df
    else:
        filtered_df = df

    # Styling the table
    styled_table = filtered_df.style.set_table_styles(
        [{'selector': 'th',
          'props': [('background-color', '#f7f7f9'),
                    ('color', 'black'),
                    ('font-weight', 'bold')]},
         {'selector': 'tr:nth-child(even)',
          'props': [('background-color', '#f2f2f2')]}]
    ).set_properties(**{
        'border': '1px solid black',
        'padding': '10px',
        'text-align': 'center'
    })

    clear_output(wait=True)
    display(widgets.VBox([key_dropdown, value_dropdown, button]))
    display(styled_table)

def create_pdfs(button):
    global filtered_df
    # Save the filtered DataFrame to an HTML file
    filtered_df.to_html('table.html')
    # Use wkhtmltopdf to convert the HTML file to a PDF
    # !wkhtmltopdf table.html table.pdf
    # Download the PDF file
    files.download('table.pdf')

# Create a dropdown widget for selecting the key (column)
key_dropdown = widgets.Dropdown(
    options=df.columns,
    description='Select key:',
    disabled=False,
)

# Create a dropdown widget for selecting the value
value_dropdown = widgets.Dropdown(
    description='Select value:',
    disabled=False,
)

# Create a button to trigger PDF creation
button = widgets.Button(description="create PDF")
button.on_click(create_pdfs)

# Update value options and table when the key is changed
key_dropdown.observe(update_value_options, names='value')
key_dropdown.observe(display_filtered_table, names='value')

# Update table when the value is changed
value_dropdown.observe(display_filtered_table, names='value')

# Initial display
display(widgets.VBox([key_dropdown, value_dropdown, button]))
# Out:
# VBox(children=(Dropdown(description='Select key:', index=1, options=('Date', 'Description', 'Document', 'Tab',…
# <style type="text/css">
# #T_9c5ce th {
#   background-color: #f7f7f9;
#   color: black;
#   font-weight: bold;
# }
# #T_9c5ce tr:nth-child(even) {
#   background-color: #f2f2f2;
# }
# #T_9c5ce_row0_col0, #T_9c5ce_row0_col1, #T_9c5ce_row0_col2, #T_9c5ce_row0_col3, #T_9c5ce_row0_col4, #T_9c5ce_row0_col5, #T_9c5ce_row1_col0, #T_9c5ce_row1_col1, #T_9c5ce_row1_col2, #T_9c5ce_row1_col3, #T_9c5ce_row1_col4, #T_9c5ce_row1_col5, #T_9c5ce_row2_col0, #T_9c5ce_row2_col1, #T_9c5ce_row2_col2, #T_9c5ce_row2_col3, #T_9c5ce_row2_col4, #T_9c5ce_row2_col5, #T_9c5ce_row3_col0, #T_9c5ce_row3_col1, #T_9c5ce_row3_col2, #T_9c5ce_row3_col3, #T_9c5ce_row3_col4, #T_9c5ce_row3_col5, #T_9c5ce_row4_col0, #T_9c5ce_row4_col1, #T_9c5ce_row4_col2, #T_9c5ce_row4_col3, #T_9c5ce_row4_col4, #T_9c5ce_row4_col5, #T_9c5ce_row5_col0, #T_9c5ce_row5_col1, #T_9c5ce_row5_col2, #T_9c5ce_row5_col3, #T_9c5ce_row5_col4, #T_9c5ce_row5_col5, #T_9c5ce_row6_col0, #T_9c5ce_row6_col1, #T_9c5ce_row6_col2, #T_9c5ce_row6_col3, #T_9c5ce_row6_col4, #T_9c5ce_row6_col5, #T_9c5ce_row7_col0, #T_9c5ce_row7_col1, #T_9c5ce_row7_col2, #T_9c5ce_row7_col3, #T_9c5ce_row7_col4, #T_9c5ce_row7_col5, #T_9c5ce_row8_col0, #T_9c5ce_row8_col1, #T_9c5ce_row8_col2, #T_9c5ce_row8_col3, #T_9c5ce_row8_col4, #T_9c5ce_row8_col5, #T_9c5ce_row9_col0, #T_9c5ce_row9_col1, #T_9c5ce_row9_col2, #T_9c5ce_row9_col3, #T_9c5ce_row9_col4, #T_9c5ce_row9_col5, #T_9c5ce_row10_col0, #T_9c5ce_row10_col1, #T_9c5ce_row10_col2, #T_9c5ce_row10_col3, #T_9c5ce_row10_col4, #T_9c5ce_row10_col5, #T_9c5ce_row11_col0, #T_9c5ce_row11_col1, #T_9c5ce_row11_col2, #T_9c5ce_row11_col3, #T_9c5ce_row11_col4, #T_9c5ce_row11_col5, #T_9c5ce_row12_col0, #T_9c5ce_row12_col1, #T_9c5ce_row12_col2, #T_9c5ce_row12_col3, #T_9c5ce_row12_col4, #T_9c5ce_row12_col5, #T_9c5ce_row13_col0, #T_9c5ce_row13_col1, #T_9c5ce_row13_col2, #T_9c5ce_row13_col3, #T_9c5ce_row13_col4, #T_9c5ce_row13_col5, #T_9c5ce_row14_col0, #T_9c5ce_row14_col1, #T_9c5ce_row14_col2, #T_9c5ce_row14_col3, #T_9c5ce_row14_col4, #T_9c5ce_row14_col5, #T_9c5ce_row15_col0, #T_9c5ce_row15_col1, #T_9c5ce_row15_col2, #T_9c5ce_row15_col3, #T_9c5ce_row15_col4, #T_9c5ce_row15_col5, #T_9c5ce_row16_col0, #T_9c5ce_row16_col1, #T_9c5ce_row16_col2, #T_9c5ce_row16_col3, #T_9c5ce_row16_col4, #T_9c5ce_row16_col5, #T_9c5ce_row17_col0, #T_9c5ce_row17_col1, #T_9c5ce_row17_col2, #T_9c5ce_row17_col3, #T_9c5ce_row17_col4, #T_9c5ce_row17_col5, #T_9c5ce_row18_col0, #T_9c5ce_row18_col1, #T_9c5ce_row18_col2, #T_9c5ce_row18_col3, #T_9c5ce_row18_col4, #T_9c5ce_row18_col5, #T_9c5ce_row19_col0, #T_9c5ce_row19_col1, #T_9c5ce_row19_col2, #T_9c5ce_row19_col3, #T_9c5ce_row19_col4, #T_9c5ce_row19_col5 {
#   border: 1px solid black;
#   padding: 10px;
#   text-align: center;
# }
# </style>
# <table id="T_9c5ce" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9c5ce_level0_col0" class="col_heading level0 col0" >Date</th>
#       <th id="T_9c5ce_level0_col1" class="col_heading level0 col1" >Description</th>
#       <th id="T_9c5ce_level0_col2" class="col_heading level0 col2" >Document</th>
#       <th id="T_9c5ce_level0_col3" class="col_heading level0 col3" >Tab</th>
#       <th id="T_9c5ce_level0_col4" class="col_heading level0 col4" >Time</th>
#       <th id="T_9c5ce_level0_col5" class="col_heading level0 col5" >User</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9c5ce_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9c5ce_row0_col0" class="data row0 col0" >2023-03-26</td>
#       <td id="T_9c5ce_row0_col1" class="data row0 col1" >Close document</td>
#       <td id="T_9c5ce_row0_col2" class="data row0 col2" >ex2StudentB1</td>
#       <td id="T_9c5ce_row0_col3" class="data row0 col3" >N/A</td>
#       <td id="T_9c5ce_row0_col4" class="data row0 col4" >08:05:26</td>
#       <td id="T_9c5ce_row0_col5" class="data row0 col5" >StudentA</td>
#     </tr>
#     <tr>
#       <th id="T_9c5ce_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_9c5ce_row1_col0" class="data row1 col0" >2023-03-25</td>
#       <td id="T_9c5ce_row1_col1" class="data row1 col1" >Close document</td>
#       <td id="T_9c5ce_row1_col2" class="data row1 col2" >ex2StudentB1</td>
#       <td id="T_9c5ce_row1_col3" class="data row1 col3" >N/A</td>
#       <td id="T_9c5ce_row1_col4" class="data row1 col4" >15:09:31</td>
#       <td id="T_9c5ce_row1_col5" class="data row1 col5" >StudentB</td>
#     </tr>
#     <tr>
#       <th id="T_9c5ce_level0_row2" class="row_heading level0 row2" >8</th>
#       <td id="T_9c5ce_row2_col0" class="data row2 col0" >2023-03-23</td>
#       <td id="T_9c5ce_row2_col1" class="data row2 col1" >Close document</td>
#       <td id="T_9c5ce_row2_col2" class="data row2 col2" >ex2StudentB1</td>
#       <td id="T_9c5ce_row2_col3" class="data row2 col3" >N/A</td>
#       <td id="T_9c5ce_row2_col4" class="data row2 col4" >10:43:58</td>
#       <td id="T_9c5ce_row2_col5" class="data row2 col5" >StudentB</td>
#     </tr>
#     <tr>
#       <th id="T_9c5ce_level0_row3" class="row_heading level0 row3" >13</th>
#       <td id="T_9c5ce_row3_col0" class="data row3 col0" >2023-03-22</td>
#       <td id="T_9c5ce_row3_col1" class="data row3 col1" >Close document</td>
#       <td id="T_9c5ce_row3_col2" class="data row3 col2" >ex2StudentB1</td>
#       <td id="T_9c5ce_row3_col3" class="data row3 col3" >N/A</td>
#       <td id="T_9c5ce_row3_col4" class="data row3 col4" >17:56:03</td>
#       <td id="T_9c5ce_row3_col5" class="data row3 col5" >StudentC</td>
#     </tr>
#     <tr>
#       <th id="T_9c5ce_level0_row4" class="row_heading level0 row4" >51</th>
#       <td id="T_9c5ce_row4_col0" class="data row4 col0" >2023-03-22</td>
#       <td id="T_9c5ce_row4_col1" class="data row4 col1" >Close document</td>
#       <td id="T_9c5ce_row4_col2" class="data row4 col2" >ex2StudentB1</td>
#       <td id="T_9c5ce_row4_col3" class="data row4 col3" >N/A</td>
#       <td id="T_9c5ce_row4_col4" class="data row4 col4" >09:10:04</td>
#       <td id="T_9c5ce_row4_col5" class="data row4 col5" >StudentC</td>
#     </tr>
#     <tr>
#       <th id="T_9c5ce_level0_row5" class="row_heading level0 row5" >383</th>
#       <td id="T_9c5ce_row5_col0" class="data row5 col0" >2023-03-22</td>
#       <td id="T_9c5ce_row5_col1" class="data row5 col1" >Close document</td>
#       <td id="T_9c5ce_row5_col2" class="data row5 col2" >ex2StudentB1</td>
#       <td id="T_9c5ce_row5_col3" class="data row5 col3" >N/A</td>
#       <td id="T_9c5ce_row5_col4" class="data row5 col4" >08:07:03</td>
#       <td id="T_9c5ce_row5_col5" class="data row5 col5" >StudentC</td>
#     </tr>
#     <tr>
#       <th id="T_9c5ce_level0_row6" class="row_heading level0 row6" >433</th>
#       <td id="T_9c5ce_row6_col0" class="data row6 col0" >2023-03-21</td>
#       <td id="T_9c5ce_row6_col1" class="data row6 col1" >Close document</td>
#       <td id="T_9c5ce_row6_col2" class="data row6 col2" >ex2StudentB1</td>
#       <td id="T_9c5ce_row6_col3" class="data row6 col3" >N/A</td>
#       <td id="T_9c5ce_row6_col4" class="data row6 col4" >20:05:25</td>
#       <td id="T_9c5ce_row6_col5" class="data row6 col5" >StudentB</td>
#     </tr>
#     <tr>
#       <th id="T_9c5ce_level0_row7" class="row_heading level0 row7" >436</th>
#       <td id="T_9c5ce_row7_col0" class="data row7 col0" >2023-03-21</td>
#       <td id="T_9c5ce_row7_col1" class="data row7 col1" >Close document</td>
#       <td id="T_9c5ce_row7_col2" class="data row7 col2" >ex2StudentB1</td>
#       <td id="T_9c5ce_row7_col3" class="data row7 col3" >N/A</td>
#       <td id="T_9c5ce_row7_col4" class="data row7 col4" >15:52:19</td>
#       <td id="T_9c5ce_row7_col5" class="data row7 col5" >StudentC</td>
#     </tr>
#     <tr>
#       <th id="T_9c5ce_level0_row8" class="row_heading level0 row8" >440</th>
#       <td id="T_9c5ce_row8_col0" class="data row8 col0" >2023-03-21</td>
#       <td id="T_9c5ce_row8_col1" class="data row8 col1" >Close document</td>
#       <td id="T_9c5ce_row8_col2" class="data row8 col2" >ex2StudentB1</td>
#       <td id="T_9c5ce_row8_col3" class="data row8 col3" >N/A</td>
#       <td id="T_9c5ce_row8_col4" class="data row8 col4" >14:00:41</td>
#       <td id
